# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options as ChromeOptions
import time

def amazon(name):
    try:
        base_url = "https://www.amazon.in"
        search_url = f"{base_url}/s?k={name.replace(' ', '+')}"

        max_retries = 5
        product_list = []

        for retry in range(max_retries):
            try:
                # Initialize the Selenium WebDriver
                chrome_options = ChromeOptions()
                chrome_options.headless = True
                webdriver_path = r"C:\\Users\\Amaan Shaikh\\OneDrive - RizviCollegeOfEngineering\\Desktop\\Backend\\myscraper\\chromedriver-win64\\chromedriver.exe"
                service = ChromeService(executable_path=webdriver_path)
                driver = webdriver.Chrome(service=service, options=chrome_options)

                driver.get(search_url)

                # Wait for the page to load (you may need to customize the wait time)
                time.sleep(5)

                # Parse the page with BeautifulSoup
                soup = BeautifulSoup(driver.page_source, "html.parser")

                results = soup.find_all("div", {"data-component-type": "s-search-result"})

                for result in results:
                    title_elem = result.find("h2", class_="a-size-mini")
                    title = title_elem.get_text() if title_elem else "N/A"

                    # Check if the title contains the search query
                    if name.lower() not in title.lower():
                        continue

                    try:
                        price_elem = result.find("span", class_="a-price-whole")
                        # Convert price to an integer (remove currency symbol and commas)
                        price = float(price_elem.get_text().replace(",", "")) if price_elem else None
                    except (AttributeError, ValueError):
                        price = "N/A"

                    link_elem = result.find("a", class_="a-link-normal")
                    link = "https://www.amazon.in" + link_elem.get("href") if link_elem else "N/A"

                    # Extract image URL
                    try:
                        image_elem = result.find("img", class_="s-image")
                        image_url = image_elem.get("src") if image_elem else "N/A"
                    except (AttributeError, KeyError):
                        image_url = "N/A"

                    product_list.append({
                        "title": title,
                        "price": price,
                        "link": link,
                        "image_url": image_url,
                    })

                # Remove products with no price information
                product_list = [product for product in product_list if product["price"] is not None]

                # Sort the product list by price
                product_list.sort(key=lambda x: x["price"])

                return product_list[0]

            except Exception as e:
                print(f"An error occurred: {str(e)}")
                time.sleep(2)  # Wait for a few seconds before retrying

            finally:
                if driver:
                    driver.quit()

        return "Max retries reached. Unable to retrieve data from Amazon."

    except:
        return "Error occurred while searching on Amazon."



# Usage
product_name = input("Enter Product Name: ")
amazon_results = amazon(product_name)
if amazon_results != "Max retries reached. Unable to retrieve data from Amazon.":
    print(f"Title: {amazon_results['title']}")
    print(f"Price: {amazon_results['price']}")
    print(f"Link: {amazon_results['link']}")
    print(f"Image URL: {amazon_results['image_url']}")
else:
    print(amazon_results)
# Out:
# Title: Apple iPhone 13 (128GB) - Starlight
# Price: 49499
# Link: https://www.amazon.in/sspa/click?ie=UTF8&spc=MToyNzAxODQyMjIyOTI5NjQ5OjE2OTcwOTI3MTI6c3BfYXRmOjIwMDc0MjM1MTE4MTAzOjowOjo&url=%2FApple-iPhone-13-128GB-Starlight%2Fdp%2FB09G9D8KRQ%2Fref%3Dsr_1_1_sspa%3Fkeywords%3DIphone%2B13%26nsdOptOutParam%3Dtrue%26qid%3D1697092712%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hd
# Image URL: https://m.media-amazon.com/images/I/61VuVU94RnL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (256GB) - (Product) RED
# Price: 59999
# Link: https://www.amazon.in/Apple-iPhone-13-256GB-Product/dp/B09G9HDN4Q/ref=sr_1_11?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-11
# Image URL: https://m.media-amazon.com/images/I/71gm8v4uPBL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512GB) - Midnight
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512GB-Midnight/dp/B09G984RNC/ref=sr_1_12?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-12
# Image URL: https://m.media-amazon.com/images/I/61VuVU94RnL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512GB) - Pink
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512GB-Pink/dp/B09G97M122/ref=sr_1_13?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-13
# Image URL: https://m.media-amazon.com/images/I/61l9ppRIiqL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512GB) - Starlight
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512GB-Starlight/dp/B09G99B791/ref=sr_1_14?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-14
# Image URL: https://m.media-amazon.com/images/I/71GLMJ7TQiL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512GB) - Blue
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512GB-Blue/dp/B09G9JJT7M/ref=sr_1_15?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-15
# Image URL: https://m.media-amazon.com/images/I/71xb2xkN5qL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512 GB) - Green
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512-GB/dp/B09V4KHL1B/ref=sr_1_16?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-16
# Image URL: https://m.media-amazon.com/images/I/61-r9zOKBCL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 (512GB) - (Product) RED
# Price: 69499
# Link: https://www.amazon.in/Apple-iPhone-13-512GB-Product/dp/B09G95PVDX/ref=sr_1_17?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-17
# Image URL: https://m.media-amazon.com/images/I/71gm8v4uPBL._AC_UY218_.jpg
#
#
# Title: Apple iPhone 13 Mini (512GB) - Pink
# Price: 94900
# Link: https://www.amazon.in/Apple-iPhone-13-Mini-512GB/dp/B09G997HJP/ref=sr_1_18?keywords=Iphone+13&nsdOptOutParam=true&qid=1697092712&sr=8-18
# Image URL: https://m.media-amazon.com/images/I/61nPiOOv9BL._AC_UY218_.jpg
